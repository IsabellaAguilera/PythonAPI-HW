# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"




# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=" + api_key

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 607

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_name = []
country = []
date = []
cloudiness = []
humidity = []
temp_max = []
wind_speed = []
lat = []
lon = []

count = 0
set = 1

#check openweather api parameters to append responses

for city in cities: 
    try:
        response = requests.get(url + "&q=" + city).json()
        city_name.append(response['name'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        cloudiness.append(response['clouds']['all'])
        humidity.append(response['main']['humidity'])
        temp_max.append(response['main']['temp_max'])
        wind_speed.append(response['wind']['speed'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        if count > 49:
            count = 1
            set += 1
            city_name.append(city)
        else:
            count += 1
            city_name.append(city)
        print(f"Processing Record {count} of Set {set} | {city}")
    except Exception:
        print("City not found. Skipping...")
print("------------------------------\nData Retrieval Complete\n------------------------------")
# Out:
# Processing Record 1 of Set 1 | barrow
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | solano
# Processing Record 4 of Set 1 | bowen
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | cape town
# City not found. Skipping...
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | ust-nera
# Processing Record 10 of Set 1 | saskylakh
# Processing Record 11 of Set 1 | beziers
# City not found. Skipping...
# Processing Record 12 of Set 1 | mabopane
# Processing Record 13 of Set 1 | carnarvon
# Processing Record 14 of Set 1 | cherskiy
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | hobart
# City not found. Skipping...
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | riohacha
# Processing Record 19 of Set 1 | tacoronte
# Processing Record 20 of Set 1 | yellowknife
# Processing Record 21 of Set 1 | hilo
# Processing Record 22 of Set 1 | aksarka
# Processing Record 23 of Set 1 | woodway
# City not found. Skipping...
# Processing Record 24 of Set 1 | qasigiannguit
# Processing Record 25 of Set 1 | georgetown
# Processing Record 26 of Set 1 | beipiao
# Processing Record 27 of Set 1 | flin flon
# Processing Record 28 of Set 1 | sychevka
# Processing Record 29 of Set 1 | beringovskiy
# Processing Record 30 of Set 1 | gat
# Processing Record 31 of Set 1 | narsaq
# Processing Record 32 of Set 1 | thompson
# Processing Record 33 of Set 1 | santona
# Processing Record 34 of Set 1 | puerto ayora
# Processing Record 35 of Set 1 | moerai
# Processing Record 36 of Set 1 | teguise
# Processing Record 37 of Set 1 | jamestown
# Processing Record 38 of Set 1 | drovyanaya
# Processing Record 39 of Set 1 | hermanus
# Processing Record 40 of Set 1 | dukat
# Processing Record 41 of Set 1 | sampit
# City not found. Skipping...
# Processing Record 42 of Set 1 | ormara
# Processing Record 43 of Set 1 | hillsboro
# Processing Record 44 of Set 1 | dzhebariki-khaya
# Processing Record 45 of Set 1 | apatity
# Processing Record 46 of Set 1 | atuona
# Processing Record 47 of Set 1 | kodiak
# Processing Record 48 of Set 1 | nikolskoye
# Processing Record 49 of Set 1 | butaritari
# Processing Record 50 of Set 1 | wenling
# Processing Record 1 of Set 2 | okhotsk
# Processing Record 2 of Set 2 | limoges
# Processing Record 3 of Set 2 | steamboat springs
# City not found. Skipping...
# Processing Record 4 of Set 2 | port alfred
# City not found. Skipping...
# Processing Record 5 of Set 2 | hithadhoo
# Processing Record 6 of Set 2 | houma
# Processing Record 7 of Set 2 | fairbanks
# Processing Record 8 of Set 2 | tuatapere
# Processing Record 9 of Set 2 | bluff
# Processing Record 10 of Set 2 | east london
# Processing Record 11 of Set 2 | pisco
# Processing Record 12 of Set 2 | christchurch
# Processing Record 13 of Set 2 | bredasdorp
# Processing Record 14 of Set 2 | kapaa
# Processing Record 15 of Set 2 | arraial do cabo
# Processing Record 16 of Set 2 | ahipara
# Processing Record 17 of Set 2 | birao
# Processing Record 18 of Set 2 | sur
# Processing Record 19 of Set 2 | eureka
# Processing Record 20 of Set 2 | erenhot
# Processing Record 21 of Set 2 | grand baie
# Processing Record 22 of Set 2 | jintur
# Processing Record 23 of Set 2 | dhidhdhoo
# City not found. Skipping...
# Processing Record 24 of Set 2 | saint-pierre
# Processing Record 25 of Set 2 | la ronge
# Processing Record 26 of Set 2 | pandan
# Processing Record 27 of Set 2 | boende
# Processing Record 28 of Set 2 | longyearbyen
# Processing Record 29 of Set 2 | castro
# Processing Record 30 of Set 2 | saldanha
# Processing Record 31 of Set 2 | iskateley
# Processing Record 32 of Set 2 | chifeng
# Processing Record 33 of Set 2 | regeneracao
# Processing Record 34 of Set 2 | santa cruz
# Processing Record 35 of Set 2 | cabanas
# City not found. Skipping...
# Processing Record 36 of Set 2 | gouyave
# Processing Record 37 of Set 2 | darhan
# Processing Record 38 of Set 2 | huaraz
# Processing Record 39 of Set 2 | praya
# Processing Record 40 of Set 2 | port hardy
# Processing Record 41 of Set 2 | elizabeth city
# City not found. Skipping...
# Processing Record 42 of Set 2 | vaini
# Processing Record 43 of Set 2 | progreso
# Processing Record 44 of Set 2 | new norfolk
# Processing Record 45 of Set 2 | kaniama
# Processing Record 46 of Set 2 | pitkyaranta
# Processing Record 47 of Set 2 | hualmay
# Processing Record 48 of Set 2 | mar del plata
# Processing Record 49 of Set 2 | ngaoundere
# Processing Record 50 of Set 2 | victoria
# Processing Record 1 of Set 3 
# Processing Record 33 of Set 4 | constitucion
# Processing Record 34 of Set 4 | tabou
# Processing Record 35 of Set 4 | touros
# Processing Record 36 of Set 4 | kaitangata
# Processing Record 37 of Set 4 | avarua
# Processing Record 38 of Set 4 | jiuquan
# Processing Record 39 of Set 4 | port shepstone
# Processing Record 40 of Set 4 | sancraieni
# Processing Record 41 of Set 4 | fortuna
# Processing Record 42 of Set 4 | roald
# Processing Record 43 of Set 4 | batabano
# Processing Record 44 of Set 4 | nuuk
# Processing Record 45 of Set 4 | ibra
# Processing Record 46 of Set 4 | hatta
# Processing Record 47 of Set 4 | chuy
# Processing Record 48 of Set 4 | holland
# Processing Record 49 of Set 4 | hobyo
# Processing Record 50 of Set 4 | rameswaram
# Processing Record 1 of Set 5 | hasaki
# Processing Record 2 of Set 5 | lorengau
# Processing Record 3 of Set 5 | okakarara
# Processing Record 4 of Set 5 | kuytun
# Processing Record 5 of Set 5 | cabo san lucas
# Processing Record 6 of Set 5 | zvishavane
# Processing Record 7 of Set 5 | rabo de peixe
# Processing Record 8 of Set 5 | punta cardon
# Processing Record 9 of Set 5 | sabang
# Processing Record 10 of Set 5 | mount gambier
# Processing Record 11 of Set 5 | khash
# Processing Record 12 of Set 5 | rawson
# Processing Record 13 of Set 5 | banjar
# Processing Record 14 of Set 5 | kruisfontein
# Processing Record 15 of Set 5 | mehamn
# Processing Record 16 of Set 5 | dharchula
# Processing Record 17 of Set 5 | northam
# Processing Record 18 of Set 5 | kavaratti
# City not found. Skipping...
# Processing Record 19 of Set 5 | ribeira grande
# Processing Record 20 of Set 5 | codrington
# Processing Record 21 of Set 5 | tura
# Processing Record 22 of Set 5 | manadhoo
# Processing Record 23 of Set 5 | guerrero negro
# Processing Record 24 of Set 5 | tasiilaq
# Processing Record 25 of Set 5 | north bend
# Processing Record 26 of Set 5 | aklavik
# Processing Record 27 of Set 5 | porto novo
# Processing Record 28 of Set 5 | souillac
# Processing Record 29 of Set 5 | pevek
# Processing Record 30 of Set 5 | san julian
# Processing Record 31 of Set 5 | ponta do sol
# Processing Record 32 of Set 5 | lagoa
# Processing Record 33 of Set 5 | khatanga
# Processing Record 34 of Set 5 | usinsk
# Processing Record 35 of Set 5 | klaksvik
# Processing Record 36 of Set 5 | peniche
# Processing Record 37 of Set 5 | dalmatovo
# Processing Record 38 of Set 5 | buraydah
# Processing Record 39 of Set 5 | yeppoon
# Processing Record 40 of Set 5 | iralaya
# Processing Record 41 of Set 5 | lompoc
# Processing Record 42 of Set 5 | maceio
# City not found. Skipping...
# Processing Record 43 of Set 5 | voh
# Processing Record 44 of Set 5 | batticaloa
# Processing Record 45 of Set 5 | flinders
# Processing Record 46 of Set 5 | malanje
# Processing Record 47 of Set 5 | naze
# Processing Record 48 of Set 5 | hofu
# Processing Record 49 of Set 5 | bansko
# Processing Record 50 of Set 5 | ambilobe
# Processing Record 1 of Set 6 | poum
# Processing Record 2 of Set 6 | hambantota
# Processing Record 3 of Set 6 | kardla
# Processing Record 4 of Set 6 | labelle
# Processing Record 5 of Set 6 | pangnirtung
# City not found. Skipping...
# Processing Record 6 of Set 6 | bubaque
# Processing Record 7 of Set 6 | ancud
# Processing Record 8 of Set 6 | kidal
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 9 of Set 6 | samarai
# Processing Record 10 of Set 6 | marzuq
# Processing Record 11 of Set 6 | vega de alatorre
# Processing Record 12 of Set 6 | xuanhua
# City not found. Skipping...
# Processing Record 13 of Set 6 | necochea
# Processing Record 14 of Set 6 | bouna
# Processing Record 15 of Set 6 | husavik
# Processing Record 16 of Set 6 | noumea
# City not found. Skipping...
# Processing Record 17 of Set 6 | honningsvag
# Processing Record 18 of Set 6 | esperance
# Processing Record 19 of Set 6 | los llanos de aridane
# Processing Record 20 of Set 6 | ozernovskiy
# Processing Record 21 of Set 6 | arauco
# Processing Record 22 of Set 6 | bautzen
# Processing Record 23 of Set 6 | san patricio
# Processing Record 24 of Set 6 | iquique
# Processing Record 25 of Set 6 | cidreira
# Processing Record 26 of Set 6 | rudsar
# Processing Record 27 of Set 6 | nanortalik
# Processing Record 28 of Set 6 | manokwari
# Processing Record 29 of Set 6 | naples
# Processing Record 30 of Set 6 | luderitz
# Processing Record 31 of Set 6 | port-gentil
# City not found. Skipping...
# Processing Record 32 of Set 6 | yuzhnouralsk
# Processing Record 33 of Set 6 | magaria
# Processing Record 34 of Set 6 | mount isa
# Processing Record 35 of Set 6 | srandakan
# Processing Record 36 of Set 6 | pochutla
# Processing Record 37 of Set 6 | port blair
# Processing Record 38 of Set 6 | aloleng
# Processing Record 39 of Set 6 | plouzane
# Processing Record 40 of Set 6 | manaus
# Processing Record 41 of Set 6 | padang
# Processing Record 42 of Set 6 | grindavik
# Processing Record 43 of Set 6 | henties bay
# City not found. Skipping...
# Processing Record 44 of Set 6 | banes
# Processing Record 45 of Set 6 | araouane
# Processing Record 46 of Set 6 | mahon
# Processing Record 47 of Set 6 | den helder
# Processing Record 48 of Set 6 | tilichiki
# Processing Record 49 of Set 6 | inuvik
# Processing Record 50 of Set 6 | cayenne
# Processing Record 1 of Set 7 | anadyr
# Processing Record 2 of Set 7 | dudinka
# Processing Record 3 of Set 7 | paita
# Processing Record 4 of Set 7 | nouadhibou
# Processing Record 5 of Set 7 | cooma
# Processing Record 6 of Set 7 | alexandria
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 7 of Set 7 | bonthe
# Processing Record 8 of Set 7 | antofagasta
# Processing Record 9 of Set 7 | tessaoua
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 10 of Set 7 | sept-iles
# Processing Record 11 of Set 7 | vermillion
# Processing Record 12 of Set 7 | palmer
# Processing Record 13 of Set 7 | chandur
# Processing Record 14 of Set 7 | dikson
# Processing Record 15 of Set 7 | oranjemund
# Processing Record 16 of Set 7 | richards bay
# City not found. Skipping...
# Processing Record 17 of Set 7 | opuwo
# Processing Record 18 of Set 7 | quatre cocos
# Processing Record 19 of Set 7 | yamada
# Processing Record 20 of Set 7 | qaqortoq
# Processing Record 21 of Set 7 | filadelfia
# City not found. Skipping...
# Processing Record 22 of Set 7 | egvekinot
# Processing Record 23 of Set 7 | daitari
# Processing Record 24 of Set 7 | vanimo
# Processing Record 25 of Set 7 | lata
# Processing Record 26 of Set 7 | katunino
| verkhnevilyuysk
# City not found. Skipping...
# Processing Record 3 of Set 9 | alenquer
# Processing Record 4 of Set 9 | adrar
# Processing Record 5 of Set 9 | labuhan
# Processing Record 6 of Set 9 | belmonte
# Processing Record 7 of Set 9 | upata
# Processing Record 8 of Set 9 | tessalit
# Processing Record 9 of Set 9 | charters towers
# Processing Record 10 of Set 9 | kihei
# Processing Record 11 of Set 9 | kysyl-syr
# Processing Record 12 of Set 9 | bogorodskoye
# Processing Record 13 of Set 9 | nyrob
# Processing Record 14 of Set 9 | vao
# Processing Record 15 of Set 9 | boulder
# City not found. Skipping...
# Processing Record 16 of Set 9 | mitha tiwana
# Processing Record 17 of Set 9 | brynmawr
# Processing Record 18 of Set 9 | hofn
# Processing Record 19 of Set 9 | sukumo
# Processing Record 20 of Set 9 | shunyi
# Processing Record 21 of Set 9 | pentecoste
# Processing Record 22 of Set 9 | napasar
# Processing Record 23 of Set 9 | kankan
# Processing Record 24 of Set 9 | mingyue
# Processing Record 25 of Set 9 | mizdah
# Processing Record 26 of Set 9 | mega
# Processing Record 27 of Set 9 | falmouth
# Processing Record 28 of Set 9 | zyryanka
# Processing Record 29 of Set 9 | lashio
# Processing Record 30 of Set 9 | ossora
# Processing Record 31 of Set 9 | paciran
# Processing Record 32 of Set 9 | havre-saint-pierre
# Processing Record 33 of Set 9 | santiago del estero
# City not found. Skipping...
# Processing Record 34 of Set 9 | colares
# Processing Record 35 of Set 9 | passos
# Processing Record 36 of Set 9 | westport
# Processing Record 37 of Set 9 | nemuro
# Processing Record 38 of Set 9 | nabire
# Processing Record 39 of Set 9 | taoudenni
# Processing Record 40 of Set 9 | bambous virieux
# Processing Record 41 of Set 9 | ornskoldsvik
# Processing Record 42 of Set 9 | nchelenge
# Processing Record 43 of Set 9 | ewa beach
# Processing Record 44 of Set 9 | guiren
# Processing Record 45 of Set 9 | atikokan
# Processing Record 46 of Set 9 | svetlogorsk
# Processing Record 47 of Set 9 | dwarka
# Processing Record 48 of Set 9 | puerto cabezas
# Processing Record 49 of Set 9 | kahului
# Processing Record 50 of Set 9 | nakonde
# Processing Record 1 of Set 10 | otjimbingwe
# City not found. Skipping...
# Processing Record 2 of Set 10 | bahir dar
# Processing Record 3 of Set 10 | florianopolis
# Processing Record 4 of Set 10 | umm lajj
# Processing Record 5 of Set 10 | bukama
# Processing Record 6 of Set 10 | severo-yeniseyskiy
# Processing Record 7 of Set 10 | katiola
# Processing Record 8 of Set 10 | raymond
# Processing Record 9 of Set 10 | abu samrah
# City not found. Skipping...
# Processing Record 10 of Set 10 | ibirama
# Processing Record 11 of Set 10 | iqaluit
# Processing Record 12 of Set 10 | luba
# Processing Record 13 of Set 10 | zamora
# Processing Record 14 of Set 10 | utete
# City not found. Skipping...
# Processing Record 15 of Set 10 | remontnoye
# Processing Record 16 of Set 10 | dongsheng
# Processing Record 17 of Set 10 | tisul
# Processing Record 18 of Set 10 | miri
# City not found. Skipping...
# Processing Record 19 of Set 10 | iwanai
# Processing Record 20 of Set 10 | lulea
# Processing Record 21 of Set 10 | marrakesh
# Processing Record 22 of Set 10 | kurayoshi
# Processing Record 23 of Set 10 | strezhevoy
# Processing Record 24 of Set 10 | kenora
# Processing Record 25 of Set 10 | champerico
# Processing Record 26 of Set 10 | temiscaming
# Processing Record 27 of Set 10 | tabuk
# Processing Record 28 of Set 10 | neuquen
# City not found. Skipping...
# Processing Record 29 of Set 10 | nueva loja
# Processing Record 30 of Set 10 | mapastepec
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 31 of Set 10 | amberley
# City not found. Skipping...
# Processing Record 32 of Set 10 | mayumba
# Processing Record 33 of Set 10 | dunedin
# Processing Record 34 of Set 10 | sechura
# City not found. Skipping...
# Processing Record 35 of Set 10 | ribeira brava
# Processing Record 36 of Set 10 | sungairaya
# Processing Record 37 of Set 10 | pirovskoye
# Processing Record 38 of Set 10 | kokkola
# Processing Record 39 of Set 10 | pangai
# Processing Record 40 of Set 10 | sarakhs
# Processing Record 41 of Set 10 | xiongzhou
# Processing Record 42 of Set 10 | manyana
# Processing Record 43 of Set 10 | juli
# Processing Record 44 of Set 10 | sobolevo
# Processing Record 45 of Set 10 | russell
# Processing Record 46 of Set 10 | robertsport
# Processing Record 47 of Set 10 | jabinyanah
# City not found. Skipping...
# Processing Record 48 of Set 10 | aktau
# Processing Record 49 of Set 10 | mayor pablo lagerenza
# Processing Record 50 of Set 10 | beloha
# Processing Record 1 of Set 11 | torbay
# Processing Record 2 of Set 11 | murray
# City not found. Skipping...
# Processing Record 3 of Set 11 | half moon bay
# Processing Record 4 of Set 11 | szendro
# City not found. Skipping...
# Processing Record 5 of Set 11 | songjianghe
# Processing Record 6 of Set 11 | norman wells
# City not found. Skipping...
# Processing Record 7 of Set 11 | agogo
# Processing Record 8 of Set 11 | wasco
# Processing Record 9 of Set 11 | petawawa
# Processing Record 10 of Set 11 | gazanjyk
# Processing Record 11 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 12 of Set 11 | les cayes
# Processing Record 13 of Set 11 | taitung
# Processing Record 14 of Set 11 | pokrovsk
# Processing Record 15 of Set 11 | sorland
# Processing Record 16 of Set 11 | buritis
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 17 of Set 11 | kastaneai
# Processing Record 18 of Set 11 | baruun-urt
# Processing Record 19 of Set 11 | launceston
# Processing Record 20 of Set 11 | oda
# Processing Record 21 of Set 11 | kangaatsiaq
# Processing Record 22 of Set 11 | shimsk
# Processing Record 23 of Set 11 | lavrentiya
# Processing Record 24 of Set 11 | hanzhong
# Processing Record 25 of Set 11 | krasnyy kholm
# Processing Record 26 of Set 11 | epe
# Processing Record 27 of Set 11 | camacari
# Processing Record 28 of Set 11 | pervomayskiy
# Processing Record 29 of Set 11 | murdochville
# Processing Record 30 of Set 11 | itoman
# Processing Record 31 of Set 11 | yatou
# Processing Record 32 of Set 11 | bam
# Processing Record 33 of Set 11 | karratha
# Processing Record 34 of Set 11 | lancut
# Processing Record 35 of Set 11 | batemans bay
# Processing Record 36 of Set 11 | hokitika
# Processing Record 37 of Set 11 | newport
# Processing Record 38 of Set 11 | winnemucca
# Processing Record 39 of Set 11 | ratnagiri
# Processing Record 40 of Set 11 | czestochowa
# Processing Record 41 of Set 11 | bathsheba
# Processing Record 42 of Set 11 | klyuchi
# Processing Record 43 of Set 11 | jalu
# Processing Record 44 of Set 11 | luwuk
# Processing Record 45 of Set 11 | salalah
# Processing Record 46 of Set 11 | iracoubo
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather = {"City":city,"Cloudiness":cloudiness,"Country":country,"Date":date,"Lat":lat,"Lng":lon,
           "Humidity":humidity,"Max Temp.":temp_max,"Wind Speed": wind_speed}

weather_df=pd.DataFrame(weather)
weather_df.count()
# Out:
# City          546
# Cloudiness    546
# Country       546
# Date          546
# Lat           546
# Lng           546
# Humidity      546
# Max Temp.     546
# Wind Speed    546
# dtype: int64

# %%
weather_df.head()
# Out:
#        City  Cloudiness Country        Date    Lat     Lng  Humidity  \
# 0  iracoubo          11      AR  1569691664 -38.31  -60.23        52
# 1  iracoubo          75      CL  1569691664 -53.16  -70.91        76
# 2  iracoubo          45      CO  1569691664   0.70  -75.25        41
# 3  iracoubo          75      AU  1569691665 -20.01  148.25        93
# 4  iracoubo          49      PF  1569691384 -23.12 -134.97        82
#
#    Max Temp.  Wind Speed
# 0      74.69       15.79
# 1      51.80        8.05
# 2      96.47        1.95
# 3      59.00        3.04
# 4      74.33       13.78

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df['Lat'],weather_df['Max Temp.'],marker="o",color="cornflowerblue",edgecolor="black")
plt.grid()
plt.title("City Latitude vs. Max Temperature (09/28/19)")
plt.xlabel ("Latitude")
plt.ylabel ("Max Temperature (F°)")
plt.savefig("lat_temp.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df['Lat'],weather_df['Humidity'],marker="o",color="cornflowerblue",edgecolor="black")
plt.grid()
plt.title("City Latitude vs. Humidity (09/28/19)")
plt.xlabel ("Latitude")
plt.ylabel ("Humidity (%)")
plt.ylim(-5,105)
plt.savefig("lat_humidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df['Lat'],weather_df['Cloudiness'],marker="o",color="cornflowerblue",edgecolor="black")
plt.grid()
plt.title("City Latitude vs. Cloudiness (09/28/19)")
plt.xlabel ("Latitude")
plt.ylabel ("Cloudiness (%)")
plt.ylim(-5,105)
plt.savefig("lat_cloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df['Lat'],weather_df['Wind Speed'],marker="o",color="cornflowerblue",edgecolor="black")
plt.grid()
plt.title("City Latitude vs. Wind Speed (09/28/19)")
plt.xlabel ("Latitude")
plt.ylabel ("Wind Speed (mph)")
plt.savefig("lat_windspeed.png")
